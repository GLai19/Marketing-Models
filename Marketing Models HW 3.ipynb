# %%
#### Import Packages ####
import gensim
from gensim import corpora,models
from gensim.models import LdaModel
from gensim.parsing.preprocessing import remove_stopwords,strip_punctuation, strip_numeric,strip_short
import pandas as pd
import unidecode

# %%
#Import Data
data=pd.read_csv("/Users/guan-hunglai/Desktop/Homework3/hwTagsSample.csv") # Import the data
data=data[["Movie","Tags"]] # Select a subset of the columns

# %%
#Draw a WordCloud (tags of all movies)
from wordcloud import WordCloud
import matplotlib.pyplot as plt
Text = ''.join(reviews)
Text.lower()
WordCloud = WordCloud(background_color = "white").generate(Text)

plt.imshow(WordCloud)
plt.axis('off')
plt.rcParams['figure.figsize'] = (10,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Q2 BarPlot of Genre and its frequency
Movie=pd.read_csv("/Users/guan-hunglai/Desktop/Homework3/hwMovieTitleGenres.csv")
Movie=Movie[["Movie","Title","Genres"]] # Select a subset of the columns

df = list()
for genre in Movie["Genres"]:
    df.append(genre.split("|"))

df = pd.DataFrame(df)

df[0].value_counts()
#Drama     198  281 49 8 = 536
#Romance   102  1 77 18 6 2 = 206
#Adventure   78 75 = 153
#Crime       65 74 21 4 = 163
#Thriller    58 4   99 72 17 1 = 251
#Comedy      58 229 23 14 3 = 327
#Horror      48 32 13 2 = 95
#Sci-Fi      33 6 60 11 9 2 = 118
#Animation   31 21 8 = 60
#Fantasy     29 9 25 18 10 = 91
#Mystery     26 4 28 13 = 71
#War         21 4 26 13 3 = 67
#Children    21 10 20 4 = 55
#Musical     16 3 12 6 4 = 41
#Documentary 7  32 1 = 40
#Film-Noir   4  3 5 = 12
#Western     3  1 5 2 1 1 = 13 
#IMAX        2 1 14 7 5 1 = 30
#Action。       215
for columns in df.columns:
    df[columns].value_counts()
    
Count = [536, 206, 153, 163, 251, 327, 95, 118, 60, 91, 71, 67, 55, 41, 40, 12, 13, 30, 215]
Genre = ["Drama", "Romance", "Adventure", "Crime", "Thriller", "Comedy", "Horror", "Sci-Fi","Animation","Fantasy","Mystery","War","Children","Musical","Documentary","Film-Noir","Western","IMAX","Action"]   


plt.bar(Genre, Count)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.rcParams['figure.figsize'] = (20,10)
plt.bar(Genre, Count)
# Out:
# <BarContainer object of 19 artists>

# %%
#WordCLoud for Action
MergedData = pd.read_csv("/Users/guan-hunglai/Desktop/Homework3/MergedData.csv")
MergedData


df = MergedData[MergedData['Genres'].str.contains('Action', regex=False, case=False, na=False)]
df["Tags"]

from wordcloud import WordCloud
import matplotlib.pyplot as plt
Actions=[Actions for Actions in df["Tags"]]
TextActions = ''.join(Actions)
TextActions.lower()
WordCloud_Action = WordCloud(background_color = "white").generate(TextActions)

plt.imshow(WordCloud_Action)
plt.axis('off')
plt.show
plt.rcParams['figure.figsize'] = (15,15)

# %%
MergedData["SplitGenre"] = MergedData["Genres"].apply(lambda x:x.split("|"))
MergedData
# Out:
#       Movie                                              Title  \
# 0      1291          Indiana Jones and the Last Crusade (1989)
# 1     49961                          Notes on a Scandal (2006)
# 2      5107                                  Hart's War (2002)
# 3     98607                                     Redline (2009)
# 4     31952                          Control (Kontroll) (2003)
# 5      8207                      Day of the Jackal, The (1973)
# 6     47937                                   Severance (2006)
# 7     34338                            Aristocrats, The (2005)
# 8    118900                                        Wild (2014)
# 9     72694                                      Shrink (2009)
# 10      252                                        I.Q. (1994)
# 11      367                                   Mask, The (1994)
# 12     2634                                  Mummy, The (1959)
# 13     3259                                Far and Away (1992)
# ...

# %%
#WordCloud for Comedy
MergedData = pd.read_csv("/Users/guan-hunglai/Desktop/Homework3/MergedData.csv")
MergedData

df2 = MergedData[MergedData['Genres'].str.contains('Comedy', regex=False, case=False, na=False)]
df2["Tags"]

from wordcloud import WordCloud
import matplotlib.pyplot as plt

Comedy=[Comedy for Comedy in df2["Tags"]]
TextComedy = ''.join(Comedy)
TextComedy.lower()
WordCloud_Comedy = WordCloud(background_color = "white").generate(TextComedy)

plt.imshow(WordCloud_Comedy)
plt.axis('off')
plt.show
plt.rcParams['figure.figsize'] = (15,15)

# %%
#Get Text/Text Preparation
reviews=[review for review in data["Tags"]]
reviews
Text = ''.join(reviews)
Text = Text.lower()
Text = strip_punctuation(Text)
Text = strip_numeric(strip_punctuation(Text))
Text = remove_stopwords(Text).split()

# %%
#Preparing Corpus
import numpy as np
def preprocess(doc):
    return(strip_short(remove_stopwords(strip_numeric(strip_punctuation(doc.lower()))),3).split())


corpus=[preprocess(review) for review in reviews]
dictionary = corpora.Dictionary(corpus)
#print(dictionary.token2id)
corpus = [dictionary.doc2bow(preprocess(review)) for review in reviews]
#print([[dictionary[id], freq] for id, freq in corpus[0]])
tfidf = models.TfidfModel(corpus, smartirs='ntc')
#print([[dictionary[id], np.around(freq, decimals=2)] for id, freq in tfidf[corpus[0]]])

# %%
#Filter Infrequent Words
dictionary.filter_extremes(no_below=2, no_above=0.99)
corpus = [dictionary.doc2bow(preprocess(review)) for review in reviews]

# %%
#LDA
lda_model = LdaModel(corpus=corpus,  # This code runs your lda
                         id2word=dictionary, 
                         random_state=100, 
                         num_topics=15,
                         passes=5,
                         chunksize=10000,
                         alpha='asymmetric',
                         decay=0.5,
                         offset=64,
                         eta=None,
                         eval_every=0,
                         iterations=100,
                         gamma_threshold=0.001,
                         per_word_topics=True)

# %%
#Top 10 words in each topic
lda_model.print_topics(-1)
# Out:
# [(0,
#   '0.012*"book" + 0.012*"social" + 0.011*"based" + 0.011*"commentary" + 0.009*"music" + 0.008*"sci" + 0.008*"oscar" + 0.007*"best" + 0.007*"dystopia" + 0.007*"story"'),
#  (1,
#   '0.011*"ending" + 0.011*"twist" + 0.010*"nonlinear" + 0.010*"time" + 0.010*"psychology" + 0.008*"travel" + 0.007*"noir" + 0.007*"memory" + 0.007*"dreamlike" + 0.006*"bad"'),
#  (2,
#   '0.016*"animation" + 0.011*"disney" + 0.011*"pixar" + 0.011*"action" + 0.009*"dinosaurs" + 0.009*"comedy" + 0.008*"funny" + 0.007*"franchise" + 0.007*"nudity" + 0.007*"spielberg"'),
#  (3,
#   '0.014*"book" + 0.012*"superhero" + 0.012*"based" + 0.011*"story" + 0.011*"comic" + 0.009*"true" + 0.008*"action" + 0.007*"depp" + 0.007*"johnny" + 0.007*"hero"'),
#  (4,
#   '0.020*"comedy" + 0.017*"romance" + 0.011*"movie" + 0.010*"funny" + 0.009*"quirky" + 0.009*"good" + 0.008*"anime" + 0.008*"book" + 0.007*"feel" + 0.007*"studio"'),
#  (5,
# ...

# %%
import pyLDAvis
import pyLDAvis.gensim 
import matplotlib.pyplot as plt
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
vis
# Out:
# /anaconda3/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.059527 -0.016050       1        1  10.815512
# 10    -0.089848  0.068392       2        1  10.474549
# 3     -0.058770 -0.028352       3        1  10.205615
# 12    -0.032572 -0.079086       4        1   9.446791
# 4     -0.024979  0.061577       5        1   8.961614
# 13    -0.030011 -0.058005       6        1   8.672400
# 14     0.045391  0.062556       7        1   6.915846
# 2      0.038922 -0.037101       8        1   5.626756
# 1     -0.001299  0.040585       9        1   5.614118
# ...

# %%
Result = pyLDAvis.show(vis)

# %%
#Observation 
Movie2324 = lda_model.get_document_topics(corpus[15], minimum_probability= 0)
Movie2324
# Out:
# [(0, 0.00028360848),
#  (1, 0.00022474912),
#  (2, 0.0001864249),
#  (3, 0.00015928486),
#  (4, 0.00013905119),
#  (5, 0.00012337849),
#  (6, 0.000110881854),
#  (7, 0.000100683916),
#  (8, 9.220382e-05),
#  (9, 8.504124e-05),
#  (10, 7.891125e-05),
#  (11, 7.360557e-05),
#  (12, 0.9982161),
#  (13, 6.488091e-05),
#  (14, 6.1250794e-05)]

# %%
values = [0.00028360848,0.00022474912,0.0001864249,0.00015928486,0.00013905119,0.00012337849,0.000110881854,0.000100683916,9.220382e-05,8.504124e-05,7.891125e-05,7.360557e-05,0.9982161,6.488091e-05,6.1250794e-05]
labels = ["Topic 1","Topic 2","Topic3","Topic 4","Topic 5", "Topic 6", "Topic 7", "Topic 8", "Topic 9", "Topic 10", "Topic 11", "Topic 12", "Topic 13", "Topic 14", "Topic 15"]
import matplotlib.pyplot as plotter
figureObject, axesObject = plotter.subplots()
axesObject.pie(values, labels=labels, autopct='%1.2f',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x110421a20>,
# ...
#  [Text(-0.00098008,1.1,'Topic 1'),
#   Text(-0.00273684,1.1,'Topic 2'),
#   Text(-0.00415774,1.09999,'Topic3'),
#   Text(-0.00535242,1.09999,'Topic 4'),
#   Text(-0.00638338,1.09998,'Topic 5'),
#   Text(-0.00729025,1.09998,'Topic 6'),
#   Text(-0.00809978,1.09997,'Topic 7'),
#   Text(-0.00883088,1.09996,'Topic 8'),
#   Text(-0.00949743,1.09996,'Topic 9'),
#   Text(-0.0101099,1.09995,'Topic 10'),
#   Text(-0.0106765,1.09995,'Topic 11'),
#   Text(-0.0112035,1.09994,'Topic 12'),
#   Text(0.00529289,-1.09999,'Topic 13'),
#   Text(0.000648034,1.1,'Topic 14'),
#   Text(0.000212154,1.1,'Topic 15')],
#  [Text(-0.000534589,0.6,'0.03'),
#   Text(-0.00149282,0.599998,'0.02'),
#   Text(-0.00226786,0.599996,'0.02'),
#   Text(-0.0029195,0.599993,'0.02'),
#   Text(-0.00348184,0.59999,'0.01'),
#   Text(-0.0039765,0.599987,'0.01'),
#   Text(-0.00441806,0.599984,'0.01'),
#   Text(-0.00481684,0.599981,'0.01'),
#   Text(-0.00518041,0.599978,'0.01'),
# ...

# %%
#Topic Proportion for movie 2324
data2 = data[data["Movie"] == 2324]
data2["Tags"]

twothree =[tag for tag in data2["Tags"]]
twothree
Text3 = ''.join(twothree)
Text3 = Text3.lower()
Text3 = strip_punctuation(Text3)
Text3 = strip_numeric(strip_punctuation(Text3))
Text3 = remove_stopwords(Text3).split()
Text3
# Out:
# ['oscar',
#  'best',
#  'foreign',
#  'language',
#  'film',
#  'holocaust',
#  'italian',
#  'father',
#  'son',
#  'relationship',
#  'roberto',
#  'benigni',
#  'sentimental',
#  'heartwarming',
#  'holocaust',
#  'oscar',
#  'best',
#  'actor',
#  'oscar',
#  'best',
#  'foreign',
#  'language',
#  'film',
#  'tearjerking',
#  'world',
#  'war',
#  'ii',
#  'roberto',
#  'benigni',
#  'holocaust',
#  'soul',
#  'humane',
#  'oscar',
#  'best',
#  'foreign',
#  'language',
#  'film',
#  'tearjerking',
#  'world',
#  'war',
#  'ii',
#  'bittersweet',
#  'heartwarming',
#  'menacing',
#  'poignant',
#  'sentimental',
#  'tearjerking',
#  'whimsical',
#  'father',
#  'son',
#  'relationship',
#  'holocaust',
#  'survival',
#  'bittersweet',
#  'father',
#  'son',
#  'relationship',
#  'funny',
#  'love',
#  'sad',
#  'ending',
#  'sentimental',
#  'bittersweet',
#  'holocaust',
#  'world',
#  'war',
#  'ii',
#  'bittersweet',
#  'father',
#  'son',
#  'relationship',
# ...
